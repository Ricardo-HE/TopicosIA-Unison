# %% [markdown]
# # Aprendizaje supervisado
#
# Esta libreta no representa el trabajo final de esta tarea, solo es usado para genera las gráficas. El verdadero trabajo esta en mi [blog](https://ricardohe97.github.io/post/teoria-de-clasificadores/)

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import sklearn.metrics

# %%
H1 = []

# %% [markdown]
# ### $H1$
#
# #### 10 Datos

# %%
no_datos = 5
#datos = (np.random.uniform(-1,1,5))
datos = [(random.uniform(-1,1), random.uniform(-1,1)) for _ in range(no_datos)]
h1 = [(datos[i][0] + datos[i][1])/2 for i in range(no_datos)]
H1.append(h1)

fig, ax = plt.subplots()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
x1 = np.linspace(-1,1,300)
y1 = np.sin(np.pi*x1)

ax.plot(x1, y1)
for i in range(no_datos):
    ax.hlines(h1[i], xmax=1, xmin=-1)

plt.title(r'$H1$ - 10 datos', fontsize=20)
plt.xlabel(r'$x$', fontsize=18)
plt.ylabel(r'$y$', fontsize=18)
    
plt.savefig('H1-10-2.png')

# %% [markdown]
# #### 50 Datos

# %%
no_datos = 25

#datos = (np.random.uniform(-1,1,5))
datos = [(random.uniform(-1,1), random.uniform(-1,1)) for _ in range(no_datos)]
h1 = [(datos[i][0] + datos[i][1])/2 for i in range(no_datos)]
H1.append(h1)

fig, ax = plt.subplots()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
x1 = np.linspace(-1,1,300)
y1 = np.sin(np.pi*x1)

ax.plot(x1, y1)
for i in range(no_datos):
    ax.hlines(h1[i], xmax=1, xmin=-1)
    
plt.title(r'$H1$ - 50 datos', fontsize=20)
plt.xlabel(r'$x$', fontsize=18)
plt.ylabel(r'$y$', fontsize=18)
    
plt.savefig('H1-50-2.png')

# %% [markdown]
# #### 100 Datos

# %%
no_datos = 50

#datos = (np.random.uniform(-1,1,5))
datos = [(random.uniform(-1,1), random.uniform(-1,1)) for _ in range(no_datos)]
h1 = [(datos[i][0] + datos[i][1])/2 for i in range(no_datos)]
H1.append(h1)

fig, ax = plt.subplots()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
x1 = np.linspace(-1,1,300)
y1 = np.sin(np.pi*x1)

ax.plot(x1, y1)
for i in range(no_datos):
    ax.hlines(h1[i], xmax=1, xmin=-1)
    
plt.title(r'$H1$ - 100 datos', fontsize=20)
plt.xlabel(r'$x$', fontsize=18)
plt.ylabel(r'$y$', fontsize=18)
# Out:
# Text(0,0.5,'$y$')

# %% [markdown]
# #### 1000 Datos

# %%
no_datos = 500

#datos = (np.random.uniform(-1,1,5))
datos = [(random.uniform(-1,1), random.uniform(-1,1)) for _ in range(no_datos)]
h1 = [(datos[i][0] + datos[i][1])/2 for i in range(no_datos)]
H1.append(h1)

fig, ax = plt.subplots()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
x1 = np.linspace(-1,1,300)
y1 = np.sin(np.pi*x1)

ax.plot(x1, y1)
for i in range(no_datos):
    ax.hlines(h1[i], xmax=1, xmin=-1)

plt.title(r'$H1$ - 1000 datos', fontsize=20)
plt.xlabel(r'$x$', fontsize=18)
plt.ylabel(r'$y$', fontsize=18)
# Out:
# Text(0,0.5,'$y$')

# %% [markdown]
# ### $H2$

# %%
H2_a = []
H2_b = []

# %% [markdown]
# #### 10 Datos

# %%
no_datos = 5

#datos = (np.random.uniform(-1,1,5))
x = [(random.uniform(-1,1), random.uniform(-1,1)) for _ in range(no_datos)]
y = [(np.sin(d[0]), np.sin(d[1])) for d in x]

a = np.array([(y_[1] - y_[0])/(x_[1]-x_[0]) for x_,y_ in zip(x,y)])
b = np.array([y[i][0] - a[i]*x[i][0] for i in range(no_datos)])

H2_a.append(list(a))
H2_b.append(list(b))

fig, ax = plt.subplots()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
x1 = np.linspace(-1,1,300)
y1 = np.sin(np.pi*x1)

ax.plot(x1, y1)
for i in range(no_datos):
    h2 = a[i]*x1 + b[i]
    ax.plot(x1, h2)

plt.title(r'$H2$ - 10 datos', fontsize=20)
plt.xlabel(r'$x$', fontsize=18)
plt.ylabel(r'$y$', fontsize=18)
# Out:
# Text(0,0.5,'$y$')

# %% [markdown]
# #### 50 Datos

# %%
no_datos = 25

#datos = (np.random.uniform(-1,1,5))
x = [(random.uniform(-1,1), random.uniform(-1,1)) for _ in range(no_datos)]
y = [(np.sin(d[0]), np.sin(d[1])) for d in x]

a = np.array([(y_[1] - y_[0])/(x_[1]-x_[0]) for x_,y_ in zip(x,y)])
b = np.array([y[i][0] - a[i]*x[i][0] for i in range(no_datos)])

H2_a.append(list(a))
H2_b.append(list(b))

fig, ax = plt.subplots()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
x1 = np.linspace(-1,1,300)
y1 = np.sin(np.pi*x1)

ax.plot(x1, y1)
for i in range(no_datos):
    h2 = a[i]*x1 + b[i]
    ax.plot(x1, h2)

plt.title(r'$H2$ - 50 datos', fontsize=20)
plt.xlabel(r'$x$', fontsize=18)
plt.ylabel(r'$y$', fontsize=18)
# Out:
# Text(0,0.5,'$y$')

# %% [markdown]
# #### 100 Datos

# %%
no_datos = 50

#datos = (np.random.uniform(-1,1,5))
x = [(random.uniform(-1,1), random.uniform(-1,1)) for _ in range(no_datos)]
y = [(np.sin(d[0]), np.sin(d[1])) for d in x]

a = np.array([(y_[1] - y_[0])/(x_[1]-x_[0]) for x_,y_ in zip(x,y)])
b = np.array([y[i][0] - a[i]*x[i][0] for i in range(no_datos)])

H2_a.append(list(a))
H2_b.append(list(b))

fig, ax = plt.subplots()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
x1 = np.linspace(-1,1,300)
y1 = np.sin(np.pi*x1)

ax.plot(x1, y1)
for i in range(no_datos):
    h2 = a[i]*x1 + b[i]
    ax.plot(x1, h2)

plt.title(r'$H2$ - 100 datos', fontsize=20)
plt.xlabel(r'$x$', fontsize=18)
plt.ylabel(r'$y$', fontsize=18)
# Out:
# Text(0,0.5,'$y$')

# %% [markdown]
# #### 1000 Datos

# %%
no_datos = 500

#datos = (np.random.uniform(-1,1,5))
x = [(random.uniform(-1,1), random.uniform(-1,1)) for _ in range(no_datos)]
y = [(np.sin(d[0]), np.sin(d[1])) for d in x]

a = np.array([(y_[1] - y_[0])/(x_[1]-x_[0]) for x_,y_ in zip(x,y)])
b = np.array([y[i][0] - a[i]*x[i][0] for i in range(no_datos)])

H2_a.append(list(a))
H2_b.append(list(b))

fig, ax = plt.subplots()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
x1 = np.linspace(-1,1,300)
y1 = np.sin(np.pi*x1)

ax.plot(x1, y1)
for i in range(no_datos):
    h2 = a[i]*x1 + b[i]
    ax.plot(x1, h2)

plt.title(r'$H2$ - 1000 datos', fontsize=20)
plt.xlabel(r'$x$', fontsize=18)
plt.ylabel(r'$y$', fontsize=18)
# Out:
# Text(0,0.5,'$y$')

# %% [markdown]
# ### Bias y varianza

# %%
biases = [np.mean([(np.sin(np.pi*np.random.uniform(-1,1)) - h_1)**2 for h_1 in H1[i]]) for i in range(4)]
variances = [np.mean([np.var(h_1)]) for h_1 in H1]
fig, ax = plt.subplots()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ax.plot([10,50,100,1000], biases, 'ro', label='Bias')
ax.plot([10,50,100,1000], variances, 'bs', label='Varianza')

legend = ax.legend(loc='best', fontsize='x-large')

plt.title('Bias y varianza para H1', fontsize=20)
plt.xlabel('No. de datos', fontsize=18)
plt.ylabel('Media', fontsize=18)



#biases = [np.mean((f - (h_m * x + h_b))**2) for h_m, h_b in zip(hypotesis_m, hypotesis_b)]
#variances = [np.mean([np.var(m * x + b) for m, b in zip(h_m, h_b)]) for h_m, h_b in zip(all_hyp_m, all_hyp_b)]
#plt.plot([10, 50, 100, 1000], biases, [10, 50, 100, 1000], variances)
# Out:
# Text(0,0.5,'Media')

# %%
x = np.linspace(-1, 1, 300)
f = np.sin(np.pi * x)

biases = [np.mean([(f - (h_m*x + h_b))**2 for h_m, h_b in zip(H2_a[i], H2_b[i])]) for i in range(4)]
variances = [np.var([h_m*x + h_b for h_m, h_b in zip(H2_a[i], H2_b[i])]) for i in range(4)]
#biases = [np.mean([np.abs((np.sin(np.pi*np.random.uniform(-1,1)) - h_1)) for h_1 in H1[i]]) for i in range(4)]
#variances = [np.mean([np.var(h_1)]) for h_1 in H1]

fig, ax = plt.subplots()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ax.plot([10,50,100,1000], biases, 'ro', label='Bias')
ax.plot([10,50,100,1000], variances, 'bs', label='Varianza')

legend = ax.legend(loc='best', fontsize='x-large')

plt.title('Bias y varianza para H2', fontsize=20)
plt.xlabel('No. de datos', fontsize=18)
plt.ylabel('Media', fontsize=18)



#biases = [np.mean((f - (h_m * x + h_b))**2) for h_m, h_b in zip(hypotesis_m, hypotesis_b)]
#variances = [np.mean([np.var(m * x + b) for m, b in zip(h_m, h_b)]) for h_m, h_b in zip(all_hyp_m, all_hyp_b)]
#plt.plot([10, 50, 100, 1000], biases, [10, 50, 100, 1000], variances)
# Out:
# Text(0,0.5,'Media')

# %%
H2_a = []
H2_b = []

no_datos = 5

#datos = (np.random.uniform(-1,1,5))
x = [(random.uniform(-1,1), random.uniform(-1,1)) for _ in range(no_datos)]
y = [(np.sin(d[0]), np.sin(d[1])) for d in x]

a = np.array([(y_[1] - y_[0])/(x_[1]-x_[0]) for x_,y_ in zip(x,y)])
b = np.array([y[i][0] - a[i]*x[i][0] for i in range(no_datos)])

H2_a.append(list(a))
H2_b.append(list(b))

#----------------------
no_datos = 25

#datos = (np.random.uniform(-1,1,5))
x = [(random.uniform(-1,1), random.uniform(-1,1)) for _ in range(no_datos)]
y = [(np.sin(d[0]), np.sin(d[1])) for d in x]

a = np.array([(y_[1] - y_[0])/(x_[1]-x_[0]) for x_,y_ in zip(x,y)])
b = np.array([y[i][0] - a[i]*x[i][0] for i in range(no_datos)])

H2_a.append(list(a))
H2_b.append(list(b))

# --------------------
no_datos = 50

#datos = (np.random.uniform(-1,1,5))
x = [(random.uniform(-1,1), random.uniform(-1,1)) for _ in range(no_datos)]
y = [(np.sin(d[0]), np.sin(d[1])) for d in x]

a = np.array([(y_[1] - y_[0])/(x_[1]-x_[0]) for x_,y_ in zip(x,y)])
b = np.array([y[i][0] - a[i]*x[i][0] for i in range(no_datos)])

H2_a.append(list(a))
H2_b.append(list(b))

# ---------------------
no_datos = 500

#datos = (np.random.uniform(-1,1,5))
x = [(random.uniform(-1,1), random.uniform(-1,1)) for _ in range(no_datos)]
y = [(np.sin(d[0]), np.sin(d[1])) for d in x]

a = np.array([(y_[1] - y_[0])/(x_[1]-x_[0]) for x_,y_ in zip(x,y)])
b = np.array([y[i][0] - a[i]*x[i][0] for i in range(no_datos)])

H2_a.append(list(a))
H2_b.append(list(b))

x = np.linspace(-1, 1, 300)
f = np.sin(np.pi * x)

biases = [np.mean([(f - (h_m*x + h_b))**2 for h_m, h_b in zip(H2_a[i], H2_b[i])]) for i in range(4)]
variances = [np.var([h_m*x + h_b for h_m, h_b in zip(H2_a[i], H2_b[i])]) for i in range(4)]
#biases = [np.mean([np.abs((np.sin(np.pi*np.random.uniform(-1,1)) - h_1)) for h_1 in H1[i]]) for i in range(4)]
#variances = [np.mean([np.var(h_1)]) for h_1 in H1]

fig, ax = plt.subplots()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ax.plot([10,50,100,1000], biases, 'ro', label='Bias')
ax.plot([10,50,100,1000], variances, 'bs', label='Varianza')

legend = ax.legend(loc='best', fontsize='x-large')

plt.title('Bias y varianza para H2', fontsize=20)
plt.xlabel('No. de datos', fontsize=18)
plt.ylabel('Media', fontsize=18)

plt.show()
